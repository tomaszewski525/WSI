# %% [markdown]
# # WSI - ćwiczenie 6 - Uczenie się ze wzmocnieniem.
# *Tomasz Frankowski*
#
# Celem zadania była implementacja algorytmu Q-learning, oraz stworzenie agenta rozwiązującego problem Taxi.

# %%
import gym
import numpy as np
import random
from IPython.display import clear_output
from time import sleep

# %% [markdown]
# #### Importuje środowisko taxi
# Celem zadanie będzie odebranie pasażera z jednego z punktów R, G, B, Y i odwiezienie go na wskazany punkt. Litera w kolorze niebieskim oznacza punkt startowy podróży pasażera, a w kolorze fioletowym oznacza punkt docelowy. Pozycja taksówki oznaczona jest przez żółty kwadrat lub zielony w przypadku kiedy przewozimy pasażera

# %%
env = gym.make("Taxi-v3").env
env.reset()
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %% [markdown]
# Wszystkie możwliwe akcje oraz stany naszego środowiska

# %%
print(f"Wszyskie stany: {env.observation_space}")
print(f"Wszyskie akcje: {env.action_space}")
# Out:
# Wszyskie stany: Discrete(500)
# Wszyskie akcje: Discrete(6)

# %% [markdown]
# Sposób poruszania taksówki

# %% [markdown]
# Dostepne akcje <br>
# 0 - ruch o jedna pozycje w dol <br>
# 1 - ruch o jedna pozycja w gore <br>
# 2 - ruch o jedna pozycje w prawo<br>
# 3 - ruch o jedna pozycje w lewo<br>
# 4 - odbior pasazera<br>
# 5 - zrzut pasazera

# %%
env.render()
env.step(2)
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)

# %% [markdown]
# ### Algorytm Q-learning

# %%
def Q_learning(alpha, gamma, epsilon, iterations, q_table, environment):

    for i in range(1, iterations):
        # reset environment
        state = environment.reset()

        reward = 0
        done = False
        
        # Iterate over enviornemnt until goal is reached
        while not done:

            # Choose action, from learned or choose random
            if random.uniform(0, 1) < epsilon:
                action = environment.action_space.sample()
            else:
                action = np.argmax(q_table[state])

            # Do action
            next_state, reward, done, info = environment.step(action) 
            
            # Actualize Q-table
            prev_state = q_table[state, action]
            future_max_state = np.max(q_table[next_state])
            q_table[state, action]  = (1 - alpha) * prev_state + alpha * (reward + gamma * future_max_state)

            state = next_state
            
    return q_table

# %% [markdown]
# ### Trenowanie agenta

# %%
# Example hiperparameters
alpha = 0.8
gamma = 0.6
epsilon = 0.7

q_tabela = Q_learning(alpha, gamma, epsilon, 100000, np.zeros([env.observation_space.n, env.action_space.n]), env)

# %% [markdown]
# Sprawdzam poprawność tabeli dla przykładowego stanu

# %%
env.reset()
env.render()
print(q_tabela[env.s])
next_action = np.argmax(q_tabela[env.s])
env.step(next_action)
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# [ -3.01034653  -2.67422442  -2.87192019  -3.01034997 -11.87013637
#  -11.87144288]
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)

# %% [markdown]
# Jak widzimy wykonany ruch wydaje się być sensowny ponieważ zbliżamy się po pasażera

# %% [markdown]
# ### Ewaluacja otrzymanych wyników

# %%
# Visualize taxi movement
def disp_frame(frame):
    clear_output(wait=True)
    print(frame)
    sleep(0.5)


def evaluate(episodes, q_table, environment, t_max, visualize=False):
    total_epochs = 0
    total_penalties = 0
    # Evaluation for each episode
    for _ in range(episodes):
        state = environment.reset()
        epochs = 0
        penalties = 0
        done = False
        t = 0
        while not done and t<t_max:
            # Choose best action
            action = np.argmax(q_table[state])
            # Make action
            state, reward, done, info = environment.step(action)

            if visualize:
                disp_frame(environment.render(mode='ansi'))

            # Check if taxi dropped passenger at wrong location
            if reward == -10:
                penalties += 1
            
            epochs += 1
            t += 1

        total_penalties += penalties
        total_epochs += epochs

    return episodes, total_epochs, total_penalties

# %% [markdown]
# Ewaluacja uzyskanego agenta

# %%
episodes, total_epochs, total_penalties = evaluate(1000, q_tabela, env, 100, False)

print(f"Episodes: {episodes}")
print(f"Avarage epochs per episode: {total_epochs/episodes}")
print(f"Avarage penalties per episode: {total_penalties/episodes}")
# Out:
# Episodes: 1000
# Avarage epochs per episode: 13.086
# Avarage penalties per episode: 0.0

# %% [markdown]
# Dla 10000 testów środowisko za każdym razem doszło do końcowego celu oraz taksówkarz ani razu się nie pomylił

# %% [markdown]
# ### Test różnych hiperparametrów do wyznaczenia q-table

# %%
def grid_search(environment, step, q_learn_func, evaluate_func, learn_iterations, test_episodes, test_iterations):
    best_hiperparams = []
    alpha =0.0 +step
    gamma = 0.0+step
    epsilon = 0.0+step

    best_hiperparams = [alpha, gamma, epsilon];
    q_tab = Q_learning(alpha, gamma, epsilon, learn_iterations, np.zeros([environment.observation_space.n, environment.action_space.n]), environment)
    episodes, total_epochs, total_penalties  = evaluate(test_episodes, q_tab, environment, test_iterations, False)
    best_score = total_epochs; # the less the better
    best_penalties = total_penalties; # there should be no penalties


    while alpha < 1:
        gamma = 0 + step
        while gamma < 1:
            epsilon = 0 + step
            while epsilon < 1:

                q_tab = Q_learning(alpha, gamma, epsilon, learn_iterations, np.zeros([environment.observation_space.n, environment.action_space.n]), environment)
                episodes, total_epochs, total_penalties  = evaluate(test_episodes, q_tab, environment, test_iterations, False)


                if(total_epochs < best_score and total_penalties <= best_penalties) and total_epochs != 0:
                    best_score = total_epochs; # the less the better
                    best_penalties = total_penalties; # there should be no penalties
                    best_hiperparams = [alpha, gamma, epsilon]

                print(f"Testing: alpha { alpha:.2f}, gamma {gamma:.2f}, epsilon {epsilon:.2f}")
                print(f"Total epochs: {total_epochs}")
                print(f"Total penalties: {total_penalties}")
                epsilon += step

            gamma += step
            
        alpha += step

    return best_hiperparams

# %%
best_params = grid_search(env, 0.1, Q_learning, evaluate, 1000, 10, 100)
# Out:
# Testing: alpha 0.10, gamma 0.10, epsilon 0.10
# Total epochs: 1000
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.10, epsilon 0.20
# Total epochs: 1000
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.10, epsilon 0.30
# Total epochs: 1000
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.10, epsilon 0.40
# Total epochs: 1000
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.10, epsilon 0.50
# Total epochs: 1000
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.10, epsilon 0.60
# Total epochs: 1000
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.10, epsilon 0.70
# Total epochs: 817
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.10, epsilon 0.80
# Total epochs: 731
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.10, epsilon 0.90
# Total epochs: 729
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.10, epsilon 1.00
# Total epochs: 142
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.20, epsilon 0.10
# Total epochs: 1000
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.20, epsilon 0.20
# Total epochs: 812
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.20, epsilon 0.30
# Total epochs: 1000
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.20, epsilon 0.40
# Total epochs: 1000
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.20, epsilon 0.50
# Total epochs: 908
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.20, epsilon 0.60
# Total epochs: 822
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.20, epsilon 0.70
# Total epochs: 640
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.20, epsilon 0.80
# Total epochs: 732
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.20, epsilon 0.90
# Total epochs: 388
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.20, epsilon 1.00
# Total epochs: 127
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.30, epsilon 0.10
# Total epochs: 1000
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.30, epsilon 0.20
# Total epochs: 1000
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.30, epsilon 0.30
# Total epochs: 818
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.30, epsilon 0.40
# Total epochs: 819
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.30, epsilon 0.50
# Total epochs: 910
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.30, epsilon 0.60
# Total epochs: 910
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.30, epsilon 0.70
# Total epochs: 640
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.30, epsilon 0.80
# Total epochs: 559
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.30, epsilon 0.90
# Total epochs: 562
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.30, epsilon 1.00
# Total epochs: 120
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.40, epsilon 0.10
# Total epochs: 907
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.40, epsilon 0.20
# Total epochs: 1000
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.40, epsilon 0.30
# Total epochs: 911
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.40, epsilon 0.40
# Total epochs: 906
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.40, epsilon 0.50
# Total epochs: 822
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.40, epsilon 0.60
# Total epochs: 729
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.40, epsilon 0.70
# Total epochs: 553
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.40, epsilon 0.80
# Total epochs: 643
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.40, epsilon 0.90
# Total epochs: 125
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.40, epsilon 1.00
# Total epochs: 140
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.50, epsilon 0.10
# Total epochs: 908
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.50, epsilon 0.20
# Total epochs: 1000
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.50, epsilon 0.30
# Total epochs: 1000
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.50, epsilon 0.40
# Total epochs: 823
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.50, epsilon 0.50
# Total epochs: 820
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.50, epsilon 0.60
# Total epochs: 821
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.50, epsilon 0.70
# Total epochs: 818
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.50, epsilon 0.80
# Total epochs: 382
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.50, epsilon 0.90
# Total epochs: 302
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.50, epsilon 1.00
# Total epochs: 134
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.60, epsilon 0.10
# Total epochs: 821
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.60, epsilon 0.20
# Total epochs: 827
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.60, epsilon 0.30
# Total epochs: 816
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.60, epsilon 0.40
# Total epochs: 731
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.60, epsilon 0.50
# Total epochs: 472
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.60, epsilon 0.60
# Total epochs: 823
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.60, epsilon 0.70
# Total epochs: 647
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.60, epsilon 0.80
# Total epochs: 474
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.60, epsilon 0.90
# Total epochs: 475
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.60, epsilon 1.00
# Total epochs: 139
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.70, epsilon 0.10
# Total epochs: 730
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.70, epsilon 0.20
# Total epochs: 734
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.70, epsilon 0.30
# Total epochs: 734
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.70, epsilon 0.40
# Total epochs: 555
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.70, epsilon 0.50
# Total epochs: 726
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.70, epsilon 0.60
# Total epochs: 474
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.70, epsilon 0.70
# Total epochs: 644
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.70, epsilon 0.80
# Total epochs: 206
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.70, epsilon 0.90
# Total epochs: 122
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.70, epsilon 1.00
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.80, epsilon 0.10
# Total epochs: 645
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.80, epsilon 0.20
# Total epochs: 467
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.80, epsilon 0.30
# Total epochs: 639
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.80, epsilon 0.40
# Total epochs: 733
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.80, epsilon 0.50
# Total epochs: 642
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.80, epsilon 0.60
# Total epochs: 737
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.80, epsilon 0.70
# Total epochs: 201
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.80, epsilon 0.80
# Total epochs: 471
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.80, epsilon 0.90
# Total epochs: 117
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.80, epsilon 1.00
# Total epochs: 129
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.90, epsilon 0.10
# Total epochs: 639
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.90, epsilon 0.20
# Total epochs: 558
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.90, epsilon 0.30
# Total epochs: 643
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.90, epsilon 0.40
# Total epochs: 471
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.90, epsilon 0.50
# Total epochs: 380
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.90, epsilon 0.60
# Total epochs: 212
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.90, epsilon 0.70
# Total epochs: 290
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.90, epsilon 0.80
# Total epochs: 305
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.90, epsilon 0.90
# Total epochs: 149
# Total penalties: 0
# Testing: alpha 0.10, gamma 0.90, epsilon 1.00
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 0.10, gamma 1.00, epsilon 0.10
# Total epochs: 467
# Total penalties: 98
# Testing: alpha 0.10, gamma 1.00, epsilon 0.20
# Total epochs: 381
# Total penalties: 0
# Testing: alpha 0.10, gamma 1.00, epsilon 0.30
# Total epochs: 382
# Total penalties: 0
# Testing: alpha 0.10, gamma 1.00, epsilon 0.40
# Total epochs: 388
# Total penalties: 0
# Testing: alpha 0.10, gamma 1.00, epsilon 0.50
# Total epochs: 216
# Total penalties: 0
# Testing: alpha 0.10, gamma 1.00, epsilon 0.60
# Total epochs: 299
# Total penalties: 0
# Testing: alpha 0.10, gamma 1.00, epsilon 0.70
# Total epochs: 477
# Total penalties: 0
# Testing: alpha 0.10, gamma 1.00, epsilon 0.80
# Total epochs: 314
# Total penalties: 0
# Testing: alpha 0.10, gamma 1.00, epsilon 0.90
# Total epochs: 144
# Total penalties: 0
# Testing: alpha 0.10, gamma 1.00, epsilon 1.00
# Total epochs: 121
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.10, epsilon 0.10
# Total epochs: 814
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.10, epsilon 0.20
# Total epochs: 906
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.10, epsilon 0.30
# Total epochs: 913
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.10, epsilon 0.40
# Total epochs: 1000
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.10, epsilon 0.50
# Total epochs: 909
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.10, epsilon 0.60
# Total epochs: 635
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.10, epsilon 0.70
# Total epochs: 646
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.10, epsilon 0.80
# Total epochs: 468
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.10, epsilon 0.90
# Total epochs: 136
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.10, epsilon 1.00
# Total epochs: 132
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.20, epsilon 0.10
# Total epochs: 1000
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.20, epsilon 0.20
# Total epochs: 912
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.20, epsilon 0.30
# Total epochs: 824
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.20, epsilon 0.40
# Total epochs: 825
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.20, epsilon 0.50
# Total epochs: 732
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.20, epsilon 0.60
# Total epochs: 641
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.20, epsilon 0.70
# Total epochs: 558
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.20, epsilon 0.80
# Total epochs: 386
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.20, epsilon 0.90
# Total epochs: 117
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.20, epsilon 1.00
# Total epochs: 117
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.30, epsilon 0.10
# Total epochs: 910
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.30, epsilon 0.20
# Total epochs: 825
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.30, epsilon 0.30
# Total epochs: 829
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.30, epsilon 0.40
# Total epochs: 730
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.30, epsilon 0.50
# Total epochs: 552
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.30, epsilon 0.60
# Total epochs: 636
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.30, epsilon 0.70
# Total epochs: 652
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.30, epsilon 0.80
# Total epochs: 384
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.30, epsilon 0.90
# Total epochs: 127
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.30, epsilon 1.00
# Total epochs: 140
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.40, epsilon 0.10
# Total epochs: 725
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.40, epsilon 0.20
# Total epochs: 821
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.40, epsilon 0.30
# Total epochs: 468
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.40, epsilon 0.40
# Total epochs: 825
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.40, epsilon 0.50
# Total epochs: 635
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.40, epsilon 0.60
# Total epochs: 467
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.40, epsilon 0.70
# Total epochs: 388
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.40, epsilon 0.80
# Total epochs: 742
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.40, epsilon 0.90
# Total epochs: 123
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.40, epsilon 1.00
# Total epochs: 136
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.50, epsilon 0.10
# Total epochs: 641
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.50, epsilon 0.20
# Total epochs: 649
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.50, epsilon 0.30
# Total epochs: 822
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.50, epsilon 0.40
# Total epochs: 474
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.50, epsilon 0.50
# Total epochs: 387
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.50, epsilon 0.60
# Total epochs: 657
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.50, epsilon 0.70
# Total epochs: 563
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.50, epsilon 0.80
# Total epochs: 303
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.50, epsilon 0.90
# Total epochs: 124
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.50, epsilon 1.00
# Total epochs: 118
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.60, epsilon 0.10
# Total epochs: 743
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.60, epsilon 0.20
# Total epochs: 286
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.60, epsilon 0.30
# Total epochs: 740
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.60, epsilon 0.40
# Total epochs: 826
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.60, epsilon 0.50
# Total epochs: 386
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.60, epsilon 0.60
# Total epochs: 563
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.60, epsilon 0.70
# Total epochs: 377
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.60, epsilon 0.80
# Total epochs: 203
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.60, epsilon 0.90
# Total epochs: 144
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.60, epsilon 1.00
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.70, epsilon 0.10
# Total epochs: 286
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.70, epsilon 0.20
# Total epochs: 818
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.70, epsilon 0.30
# Total epochs: 384
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.70, epsilon 0.40
# Total epochs: 553
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.70, epsilon 0.50
# Total epochs: 567
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.70, epsilon 0.60
# Total epochs: 207
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.70, epsilon 0.70
# Total epochs: 112
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.70, epsilon 0.80
# Total epochs: 126
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.70, epsilon 0.90
# Total epochs: 118
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.70, epsilon 1.00
# Total epochs: 139
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.80, epsilon 0.10
# Total epochs: 373
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.80, epsilon 0.20
# Total epochs: 562
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.80, epsilon 0.30
# Total epochs: 309
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.80, epsilon 0.40
# Total epochs: 482
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.80, epsilon 0.50
# Total epochs: 295
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.80, epsilon 0.60
# Total epochs: 369
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.80, epsilon 0.70
# Total epochs: 222
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.80, epsilon 0.80
# Total epochs: 122
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.80, epsilon 0.90
# Total epochs: 148
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.80, epsilon 1.00
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.90, epsilon 0.10
# Total epochs: 126
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.90, epsilon 0.20
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.90, epsilon 0.30
# Total epochs: 121
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.90, epsilon 0.40
# Total epochs: 205
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.90, epsilon 0.50
# Total epochs: 137
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.90, epsilon 0.60
# Total epochs: 209
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.90, epsilon 0.70
# Total epochs: 133
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.90, epsilon 0.80
# Total epochs: 119
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.90, epsilon 0.90
# Total epochs: 113
# Total penalties: 0
# Testing: alpha 0.20, gamma 0.90, epsilon 1.00
# Total epochs: 122
# Total penalties: 0
# Testing: alpha 0.20, gamma 1.00, epsilon 0.10
# Total epochs: 206
# Total penalties: 0
# Testing: alpha 0.20, gamma 1.00, epsilon 0.20
# Total epochs: 215
# Total penalties: 0
# Testing: alpha 0.20, gamma 1.00, epsilon 0.30
# Total epochs: 217
# Total penalties: 0
# Testing: alpha 0.20, gamma 1.00, epsilon 0.40
# Total epochs: 471
# Total penalties: 0
# Testing: alpha 0.20, gamma 1.00, epsilon 0.50
# Total epochs: 136
# Total penalties: 0
# Testing: alpha 0.20, gamma 1.00, epsilon 0.60
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 0.20, gamma 1.00, epsilon 0.70
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 0.20, gamma 1.00, epsilon 0.80
# Total epochs: 127
# Total penalties: 0
# Testing: alpha 0.20, gamma 1.00, epsilon 0.90
# Total epochs: 124
# Total penalties: 0
# Testing: alpha 0.20, gamma 1.00, epsilon 1.00
# Total epochs: 127
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.10, epsilon 0.10
# Total epochs: 735
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.10, epsilon 0.20
# Total epochs: 450
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.10, epsilon 0.30
# Total epochs: 728
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.10, epsilon 0.40
# Total epochs: 909
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.10, epsilon 0.50
# Total epochs: 645
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.10, epsilon 0.60
# Total epochs: 563
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.10, epsilon 0.70
# Total epochs: 385
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.10, epsilon 0.80
# Total epochs: 288
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.10, epsilon 0.90
# Total epochs: 217
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.10, epsilon 1.00
# Total epochs: 114
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.20, epsilon 0.10
# Total epochs: 909
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.20, epsilon 0.20
# Total epochs: 640
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.20, epsilon 0.30
# Total epochs: 467
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.20, epsilon 0.40
# Total epochs: 727
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.20, epsilon 0.50
# Total epochs: 639
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.20, epsilon 0.60
# Total epochs: 650
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.20, epsilon 0.70
# Total epochs: 302
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.20, epsilon 0.80
# Total epochs: 215
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.20, epsilon 0.90
# Total epochs: 222
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.20, epsilon 1.00
# Total epochs: 139
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.30, epsilon 0.10
# Total epochs: 735
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.30, epsilon 0.20
# Total epochs: 731
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.30, epsilon 0.30
# Total epochs: 822
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.30, epsilon 0.40
# Total epochs: 653
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.30, epsilon 0.50
# Total epochs: 740
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.30, epsilon 0.60
# Total epochs: 389
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.30, epsilon 0.70
# Total epochs: 479
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.30, epsilon 0.80
# Total epochs: 307
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.30, epsilon 0.90
# Total epochs: 223
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.30, epsilon 1.00
# Total epochs: 125
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.40, epsilon 0.10
# Total epochs: 476
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.40, epsilon 0.20
# Total epochs: 554
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.40, epsilon 0.30
# Total epochs: 733
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.40, epsilon 0.40
# Total epochs: 565
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.40, epsilon 0.50
# Total epochs: 467
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.40, epsilon 0.60
# Total epochs: 481
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.40, epsilon 0.70
# Total epochs: 117
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.40, epsilon 0.80
# Total epochs: 222
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.40, epsilon 0.90
# Total epochs: 113
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.40, epsilon 1.00
# Total epochs: 139
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.50, epsilon 0.10
# Total epochs: 467
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.50, epsilon 0.20
# Total epochs: 827
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.50, epsilon 0.30
# Total epochs: 558
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.50, epsilon 0.40
# Total epochs: 561
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.50, epsilon 0.50
# Total epochs: 746
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.50, epsilon 0.60
# Total epochs: 477
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.50, epsilon 0.70
# Total epochs: 207
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.50, epsilon 0.80
# Total epochs: 214
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.50, epsilon 0.90
# Total epochs: 134
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.50, epsilon 1.00
# Total epochs: 127
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.60, epsilon 0.10
# Total epochs: 112
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.60, epsilon 0.20
# Total epochs: 475
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.60, epsilon 0.30
# Total epochs: 733
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.60, epsilon 0.40
# Total epochs: 389
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.60, epsilon 0.50
# Total epochs: 295
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.60, epsilon 0.60
# Total epochs: 394
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.60, epsilon 0.70
# Total epochs: 308
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.60, epsilon 0.80
# Total epochs: 118
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.60, epsilon 0.90
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.60, epsilon 1.00
# Total epochs: 125
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.70, epsilon 0.10
# Total epochs: 472
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.70, epsilon 0.20
# Total epochs: 305
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.70, epsilon 0.30
# Total epochs: 217
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.70, epsilon 0.40
# Total epochs: 141
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.70, epsilon 0.50
# Total epochs: 309
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.70, epsilon 0.60
# Total epochs: 393
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.70, epsilon 0.70
# Total epochs: 217
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.70, epsilon 0.80
# Total epochs: 126
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.70, epsilon 0.90
# Total epochs: 142
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.70, epsilon 1.00
# Total epochs: 134
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.80, epsilon 0.10
# Total epochs: 210
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.80, epsilon 0.20
# Total epochs: 221
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.80, epsilon 0.30
# Total epochs: 298
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.80, epsilon 0.40
# Total epochs: 381
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.80, epsilon 0.50
# Total epochs: 205
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.80, epsilon 0.60
# Total epochs: 218
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.80, epsilon 0.70
# Total epochs: 134
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.80, epsilon 0.80
# Total epochs: 118
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.80, epsilon 0.90
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.80, epsilon 1.00
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.90, epsilon 0.10
# Total epochs: 306
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.90, epsilon 0.20
# Total epochs: 392
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.90, epsilon 0.30
# Total epochs: 221
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.90, epsilon 0.40
# Total epochs: 220
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.90, epsilon 0.50
# Total epochs: 140
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.90, epsilon 0.60
# Total epochs: 135
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.90, epsilon 0.70
# Total epochs: 138
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.90, epsilon 0.80
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.90, epsilon 0.90
# Total epochs: 143
# Total penalties: 0
# Testing: alpha 0.30, gamma 0.90, epsilon 1.00
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 0.30, gamma 1.00, epsilon 0.10
# Total epochs: 125
# Total penalties: 0
# Testing: alpha 0.30, gamma 1.00, epsilon 0.20
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 0.30, gamma 1.00, epsilon 0.30
# Total epochs: 223
# Total penalties: 0
# Testing: alpha 0.30, gamma 1.00, epsilon 0.40
# Total epochs: 137
# Total penalties: 0
# Testing: alpha 0.30, gamma 1.00, epsilon 0.50
# Total epochs: 124
# Total penalties: 0
# Testing: alpha 0.30, gamma 1.00, epsilon 0.60
# Total epochs: 135
# Total penalties: 0
# Testing: alpha 0.30, gamma 1.00, epsilon 0.70
# Total epochs: 133
# Total penalties: 0
# Testing: alpha 0.30, gamma 1.00, epsilon 0.80
# Total epochs: 135
# Total penalties: 0
# Testing: alpha 0.30, gamma 1.00, epsilon 0.90
# Total epochs: 137
# Total penalties: 0
# Testing: alpha 0.30, gamma 1.00, epsilon 1.00
# Total epochs: 125
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.10, epsilon 0.10
# Total epochs: 560
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.10, epsilon 0.20
# Total epochs: 732
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.10, epsilon 0.30
# Total epochs: 914
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.10, epsilon 0.40
# Total epochs: 640
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.10, epsilon 0.50
# Total epochs: 644
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.10, epsilon 0.60
# Total epochs: 306
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.10, epsilon 0.70
# Total epochs: 556
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.10, epsilon 0.80
# Total epochs: 214
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.10, epsilon 0.90
# Total epochs: 137
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.10, epsilon 1.00
# Total epochs: 133
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.20, epsilon 0.10
# Total epochs: 732
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.20, epsilon 0.20
# Total epochs: 563
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.20, epsilon 0.30
# Total epochs: 644
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.20, epsilon 0.40
# Total epochs: 367
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.20, epsilon 0.50
# Total epochs: 477
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.20, epsilon 0.60
# Total epochs: 389
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.20, epsilon 0.70
# Total epochs: 137
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.20, epsilon 0.80
# Total epochs: 215
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.20, epsilon 0.90
# Total epochs: 137
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.20, epsilon 1.00
# Total epochs: 135
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.30, epsilon 0.10
# Total epochs: 565
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.30, epsilon 0.20
# Total epochs: 457
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.30, epsilon 0.30
# Total epochs: 470
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.30, epsilon 0.40
# Total epochs: 476
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.30, epsilon 0.50
# Total epochs: 652
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.30, epsilon 0.60
# Total epochs: 476
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.30, epsilon 0.70
# Total epochs: 118
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.30, epsilon 0.80
# Total epochs: 205
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.30, epsilon 0.90
# Total epochs: 125
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.30, epsilon 1.00
# Total epochs: 118
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.40, epsilon 0.10
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.40, epsilon 0.20
# Total epochs: 554
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.40, epsilon 0.30
# Total epochs: 473
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.40, epsilon 0.40
# Total epochs: 291
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.40, epsilon 0.50
# Total epochs: 397
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.40, epsilon 0.60
# Total epochs: 205
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.40, epsilon 0.70
# Total epochs: 649
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.40, epsilon 0.80
# Total epochs: 219
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.40, epsilon 0.90
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.40, epsilon 1.00
# Total epochs: 147
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.50, epsilon 0.10
# Total epochs: 465
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.50, epsilon 0.20
# Total epochs: 555
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.50, epsilon 0.30
# Total epochs: 297
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.50, epsilon 0.40
# Total epochs: 300
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.50, epsilon 0.50
# Total epochs: 562
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.50, epsilon 0.60
# Total epochs: 378
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.50, epsilon 0.70
# Total epochs: 386
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.50, epsilon 0.80
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.50, epsilon 0.90
# Total epochs: 135
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.50, epsilon 1.00
# Total epochs: 136
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.60, epsilon 0.10
# Total epochs: 203
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.60, epsilon 0.20
# Total epochs: 553
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.60, epsilon 0.30
# Total epochs: 400
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.60, epsilon 0.40
# Total epochs: 291
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.60, epsilon 0.50
# Total epochs: 466
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.60, epsilon 0.60
# Total epochs: 117
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.60, epsilon 0.70
# Total epochs: 122
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.60, epsilon 0.80
# Total epochs: 132
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.60, epsilon 0.90
# Total epochs: 121
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.60, epsilon 1.00
# Total epochs: 137
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.70, epsilon 0.10
# Total epochs: 213
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.70, epsilon 0.20
# Total epochs: 208
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.70, epsilon 0.30
# Total epochs: 205
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.70, epsilon 0.40
# Total epochs: 301
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.70, epsilon 0.50
# Total epochs: 216
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.70, epsilon 0.60
# Total epochs: 121
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.70, epsilon 0.70
# Total epochs: 137
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.70, epsilon 0.80
# Total epochs: 119
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.70, epsilon 0.90
# Total epochs: 133
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.70, epsilon 1.00
# Total epochs: 126
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.80, epsilon 0.10
# Total epochs: 138
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.80, epsilon 0.20
# Total epochs: 125
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.80, epsilon 0.30
# Total epochs: 225
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.80, epsilon 0.40
# Total epochs: 227
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.80, epsilon 0.50
# Total epochs: 229
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.80, epsilon 0.60
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.80, epsilon 0.70
# Total epochs: 140
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.80, epsilon 0.80
# Total epochs: 134
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.80, epsilon 0.90
# Total epochs: 133
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.80, epsilon 1.00
# Total epochs: 137
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.90, epsilon 0.10
# Total epochs: 138
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.90, epsilon 0.20
# Total epochs: 129
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.90, epsilon 0.30
# Total epochs: 129
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.90, epsilon 0.40
# Total epochs: 127
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.90, epsilon 0.50
# Total epochs: 134
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.90, epsilon 0.60
# Total epochs: 119
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.90, epsilon 0.70
# Total epochs: 125
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.90, epsilon 0.80
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.90, epsilon 0.90
# Total epochs: 126
# Total penalties: 0
# Testing: alpha 0.40, gamma 0.90, epsilon 1.00
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 0.40, gamma 1.00, epsilon 0.10
# Total epochs: 118
# Total penalties: 0
# Testing: alpha 0.40, gamma 1.00, epsilon 0.20
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 0.40, gamma 1.00, epsilon 0.30
# Total epochs: 140
# Total penalties: 0
# Testing: alpha 0.40, gamma 1.00, epsilon 0.40
# Total epochs: 137
# Total penalties: 0
# Testing: alpha 0.40, gamma 1.00, epsilon 0.50
# Total epochs: 129
# Total penalties: 0
# Testing: alpha 0.40, gamma 1.00, epsilon 0.60
# Total epochs: 202
# Total penalties: 0
# Testing: alpha 0.40, gamma 1.00, epsilon 0.70
# Total epochs: 142
# Total penalties: 0
# Testing: alpha 0.40, gamma 1.00, epsilon 0.80
# Total epochs: 126
# Total penalties: 0
# Testing: alpha 0.40, gamma 1.00, epsilon 0.90
# Total epochs: 142
# Total penalties: 0
# Testing: alpha 0.40, gamma 1.00, epsilon 1.00
# Total epochs: 133
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.10, epsilon 0.10
# Total epochs: 563
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.10, epsilon 0.20
# Total epochs: 466
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.10, epsilon 0.30
# Total epochs: 467
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.10, epsilon 0.40
# Total epochs: 646
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.10, epsilon 0.50
# Total epochs: 572
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.10, epsilon 0.60
# Total epochs: 473
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.10, epsilon 0.70
# Total epochs: 216
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.10, epsilon 0.80
# Total epochs: 125
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.10, epsilon 0.90
# Total epochs: 133
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.10, epsilon 1.00
# Total epochs: 118
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.20, epsilon 0.10
# Total epochs: 384
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.20, epsilon 0.20
# Total epochs: 560
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.20, epsilon 0.30
# Total epochs: 305
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.20, epsilon 0.40
# Total epochs: 294
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.20, epsilon 0.50
# Total epochs: 294
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.20, epsilon 0.60
# Total epochs: 562
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.20, epsilon 0.70
# Total epochs: 391
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.20, epsilon 0.80
# Total epochs: 120
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.20, epsilon 0.90
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.20, epsilon 1.00
# Total epochs: 124
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.30, epsilon 0.10
# Total epochs: 292
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.30, epsilon 0.20
# Total epochs: 554
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.30, epsilon 0.30
# Total epochs: 220
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.30, epsilon 0.40
# Total epochs: 222
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.30, epsilon 0.50
# Total epochs: 310
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.30, epsilon 0.60
# Total epochs: 219
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.30, epsilon 0.70
# Total epochs: 215
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.30, epsilon 0.80
# Total epochs: 304
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.30, epsilon 0.90
# Total epochs: 141
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.30, epsilon 1.00
# Total epochs: 136
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.40, epsilon 0.10
# Total epochs: 469
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.40, epsilon 0.20
# Total epochs: 293
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.40, epsilon 0.30
# Total epochs: 384
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.40, epsilon 0.40
# Total epochs: 206
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.40, epsilon 0.50
# Total epochs: 214
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.40, epsilon 0.60
# Total epochs: 296
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.40, epsilon 0.70
# Total epochs: 149
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.40, epsilon 0.80
# Total epochs: 137
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.40, epsilon 0.90
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.40, epsilon 1.00
# Total epochs: 124
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.50, epsilon 0.10
# Total epochs: 308
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.50, epsilon 0.20
# Total epochs: 281
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.50, epsilon 0.30
# Total epochs: 302
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.50, epsilon 0.40
# Total epochs: 210
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.50, epsilon 0.50
# Total epochs: 479
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.50, epsilon 0.60
# Total epochs: 218
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.50, epsilon 0.70
# Total epochs: 304
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.50, epsilon 0.80
# Total epochs: 129
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.50, epsilon 0.90
# Total epochs: 124
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.50, epsilon 1.00
# Total epochs: 124
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.60, epsilon 0.10
# Total epochs: 123
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.60, epsilon 0.20
# Total epochs: 121
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.60, epsilon 0.30
# Total epochs: 206
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.60, epsilon 0.40
# Total epochs: 219
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.60, epsilon 0.50
# Total epochs: 288
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.60, epsilon 0.60
# Total epochs: 303
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.60, epsilon 0.70
# Total epochs: 302
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.60, epsilon 0.80
# Total epochs: 111
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.60, epsilon 0.90
# Total epochs: 122
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.60, epsilon 1.00
# Total epochs: 135
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.70, epsilon 0.10
# Total epochs: 206
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.70, epsilon 0.20
# Total epochs: 215
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.70, epsilon 0.30
# Total epochs: 222
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.70, epsilon 0.40
# Total epochs: 223
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.70, epsilon 0.50
# Total epochs: 140
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.70, epsilon 0.60
# Total epochs: 132
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.70, epsilon 0.70
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.70, epsilon 0.80
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.70, epsilon 0.90
# Total epochs: 136
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.70, epsilon 1.00
# Total epochs: 136
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.80, epsilon 0.10
# Total epochs: 204
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.80, epsilon 0.20
# Total epochs: 207
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.80, epsilon 0.30
# Total epochs: 118
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.80, epsilon 0.40
# Total epochs: 125
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.80, epsilon 0.50
# Total epochs: 134
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.80, epsilon 0.60
# Total epochs: 133
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.80, epsilon 0.70
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.80, epsilon 0.80
# Total epochs: 129
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.80, epsilon 0.90
# Total epochs: 135
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.80, epsilon 1.00
# Total epochs: 129
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.90, epsilon 0.10
# Total epochs: 139
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.90, epsilon 0.20
# Total epochs: 124
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.90, epsilon 0.30
# Total epochs: 127
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.90, epsilon 0.40
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.90, epsilon 0.50
# Total epochs: 225
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.90, epsilon 0.60
# Total epochs: 133
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.90, epsilon 0.70
# Total epochs: 212
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.90, epsilon 0.80
# Total epochs: 143
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.90, epsilon 0.90
# Total epochs: 148
# Total penalties: 0
# Testing: alpha 0.50, gamma 0.90, epsilon 1.00
# Total epochs: 146
# Total penalties: 0
# Testing: alpha 0.50, gamma 1.00, epsilon 0.10
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 0.50, gamma 1.00, epsilon 0.20
# Total epochs: 115
# Total penalties: 0
# Testing: alpha 0.50, gamma 1.00, epsilon 0.30
# Total epochs: 216
# Total penalties: 0
# Testing: alpha 0.50, gamma 1.00, epsilon 0.40
# Total epochs: 138
# Total penalties: 0
# Testing: alpha 0.50, gamma 1.00, epsilon 0.50
# Total epochs: 151
# Total penalties: 0
# Testing: alpha 0.50, gamma 1.00, epsilon 0.60
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 0.50, gamma 1.00, epsilon 0.70
# Total epochs: 116
# Total penalties: 0
# Testing: alpha 0.50, gamma 1.00, epsilon 0.80
# Total epochs: 127
# Total penalties: 0
# Testing: alpha 0.50, gamma 1.00, epsilon 0.90
# Total epochs: 125
# Total penalties: 0
# Testing: alpha 0.50, gamma 1.00, epsilon 1.00
# Total epochs: 143
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.10, epsilon 0.10
# Total epochs: 311
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.10, epsilon 0.20
# Total epochs: 481
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.10, epsilon 0.30
# Total epochs: 389
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.10, epsilon 0.40
# Total epochs: 214
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.10, epsilon 0.50
# Total epochs: 219
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.10, epsilon 0.60
# Total epochs: 290
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.10, epsilon 0.70
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.10, epsilon 0.80
# Total epochs: 140
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.10, epsilon 0.90
# Total epochs: 135
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.10, epsilon 1.00
# Total epochs: 135
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.20, epsilon 0.10
# Total epochs: 649
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.20, epsilon 0.20
# Total epochs: 310
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.20, epsilon 0.30
# Total epochs: 132
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.20, epsilon 0.40
# Total epochs: 118
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.20, epsilon 0.50
# Total epochs: 384
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.20, epsilon 0.60
# Total epochs: 297
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.20, epsilon 0.70
# Total epochs: 221
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.20, epsilon 0.80
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.20, epsilon 0.90
# Total epochs: 151
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.20, epsilon 1.00
# Total epochs: 112
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.30, epsilon 0.10
# Total epochs: 739
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.30, epsilon 0.20
# Total epochs: 298
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.30, epsilon 0.30
# Total epochs: 467
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.30, epsilon 0.40
# Total epochs: 208
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.30, epsilon 0.50
# Total epochs: 480
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.30, epsilon 0.60
# Total epochs: 302
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.30, epsilon 0.70
# Total epochs: 302
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.30, epsilon 0.80
# Total epochs: 225
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.30, epsilon 0.90
# Total epochs: 126
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.30, epsilon 1.00
# Total epochs: 126
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.40, epsilon 0.10
# Total epochs: 289
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.40, epsilon 0.20
# Total epochs: 388
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.40, epsilon 0.30
# Total epochs: 215
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.40, epsilon 0.40
# Total epochs: 472
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.40, epsilon 0.50
# Total epochs: 391
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.40, epsilon 0.60
# Total epochs: 216
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.40, epsilon 0.70
# Total epochs: 126
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.40, epsilon 0.80
# Total epochs: 205
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.40, epsilon 0.90
# Total epochs: 145
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.40, epsilon 1.00
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.50, epsilon 0.10
# Total epochs: 389
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.50, epsilon 0.20
# Total epochs: 387
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.50, epsilon 0.30
# Total epochs: 293
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.50, epsilon 0.40
# Total epochs: 403
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.50, epsilon 0.50
# Total epochs: 205
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.50, epsilon 0.60
# Total epochs: 304
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.50, epsilon 0.70
# Total epochs: 126
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.50, epsilon 0.80
# Total epochs: 135
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.50, epsilon 0.90
# Total epochs: 137
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.50, epsilon 1.00
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.60, epsilon 0.10
# Total epochs: 204
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.60, epsilon 0.20
# Total epochs: 312
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.60, epsilon 0.30
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.60, epsilon 0.40
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.60, epsilon 0.50
# Total epochs: 215
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.60, epsilon 0.60
# Total epochs: 112
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.60, epsilon 0.70
# Total epochs: 136
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.60, epsilon 0.80
# Total epochs: 221
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.60, epsilon 0.90
# Total epochs: 120
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.60, epsilon 1.00
# Total epochs: 137
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.70, epsilon 0.10
# Total epochs: 211
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.70, epsilon 0.20
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.70, epsilon 0.30
# Total epochs: 218
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.70, epsilon 0.40
# Total epochs: 302
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.70, epsilon 0.50
# Total epochs: 135
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.70, epsilon 0.60
# Total epochs: 132
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.70, epsilon 0.70
# Total epochs: 109
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.70, epsilon 0.80
# Total epochs: 127
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.70, epsilon 0.90
# Total epochs: 135
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.70, epsilon 1.00
# Total epochs: 125
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.80, epsilon 0.10
# Total epochs: 314
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.80, epsilon 0.20
# Total epochs: 212
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.80, epsilon 0.30
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.80, epsilon 0.40
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.80, epsilon 0.50
# Total epochs: 123
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.80, epsilon 0.60
# Total epochs: 133
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.80, epsilon 0.70
# Total epochs: 124
# Total penalties: 0
# Testing: alpha 0.60, gamma 0.80, epsilon 0.80
# Total epochs: 127
# Total penalties: 0
# ...
# Total epochs: 136
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.10, epsilon 0.90
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.10, epsilon 1.00
# Total epochs: 115
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.20, epsilon 0.10
# Total epochs: 144
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.20, epsilon 0.20
# Total epochs: 394
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.20, epsilon 0.30
# Total epochs: 219
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.20, epsilon 0.40
# Total epochs: 311
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.20, epsilon 0.50
# Total epochs: 129
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.20, epsilon 0.60
# Total epochs: 203
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.20, epsilon 0.70
# Total epochs: 212
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.20, epsilon 0.80
# Total epochs: 121
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.20, epsilon 0.90
# Total epochs: 136
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.20, epsilon 1.00
# Total epochs: 135
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.30, epsilon 0.10
# Total epochs: 474
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.30, epsilon 0.20
# Total epochs: 214
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.30, epsilon 0.30
# Total epochs: 200
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.30, epsilon 0.40
# Total epochs: 117
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.30, epsilon 0.50
# Total epochs: 212
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.30, epsilon 0.60
# Total epochs: 137
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.30, epsilon 0.70
# Total epochs: 112
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.30, epsilon 0.80
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.30, epsilon 0.90
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.30, epsilon 1.00
# Total epochs: 143
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.40, epsilon 0.10
# Total epochs: 225
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.40, epsilon 0.20
# Total epochs: 121
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.40, epsilon 0.30
# Total epochs: 215
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.40, epsilon 0.40
# Total epochs: 218
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.40, epsilon 0.50
# Total epochs: 126
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.40, epsilon 0.60
# Total epochs: 124
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.40, epsilon 0.70
# Total epochs: 137
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.40, epsilon 0.80
# Total epochs: 135
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.40, epsilon 0.90
# Total epochs: 135
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.40, epsilon 1.00
# Total epochs: 127
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.50, epsilon 0.10
# Total epochs: 136
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.50, epsilon 0.20
# Total epochs: 216
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.50, epsilon 0.30
# Total epochs: 132
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.50, epsilon 0.40
# Total epochs: 136
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.50, epsilon 0.50
# Total epochs: 141
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.50, epsilon 0.60
# Total epochs: 140
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.50, epsilon 0.70
# Total epochs: 136
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.50, epsilon 0.80
# Total epochs: 134
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.50, epsilon 0.90
# Total epochs: 132
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.50, epsilon 1.00
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.60, epsilon 0.10
# Total epochs: 129
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.60, epsilon 0.20
# Total epochs: 142
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.60, epsilon 0.30
# Total epochs: 119
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.60, epsilon 0.40
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.60, epsilon 0.50
# Total epochs: 140
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.60, epsilon 0.60
# Total epochs: 214
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.60, epsilon 0.70
# Total epochs: 133
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.60, epsilon 0.80
# Total epochs: 121
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.60, epsilon 0.90
# Total epochs: 133
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.60, epsilon 1.00
# Total epochs: 123
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.70, epsilon 0.10
# Total epochs: 121
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.70, epsilon 0.20
# Total epochs: 129
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.70, epsilon 0.30
# Total epochs: 122
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.70, epsilon 0.40
# Total epochs: 134
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.70, epsilon 0.50
# Total epochs: 219
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.70, epsilon 0.60
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.70, epsilon 0.70
# Total epochs: 116
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.70, epsilon 0.80
# Total epochs: 138
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.70, epsilon 0.90
# Total epochs: 136
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.70, epsilon 1.00
# Total epochs: 126
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.80, epsilon 0.10
# Total epochs: 134
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.80, epsilon 0.20
# Total epochs: 121
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.80, epsilon 0.30
# Total epochs: 135
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.80, epsilon 0.40
# Total epochs: 126
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.80, epsilon 0.50
# Total epochs: 127
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.80, epsilon 0.60
# Total epochs: 127
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.80, epsilon 0.70
# Total epochs: 143
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.80, epsilon 0.80
# Total epochs: 126
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.80, epsilon 0.90
# Total epochs: 144
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.80, epsilon 1.00
# Total epochs: 147
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.90, epsilon 0.10
# Total epochs: 126
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.90, epsilon 0.20
# Total epochs: 136
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.90, epsilon 0.30
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.90, epsilon 0.40
# Total epochs: 138
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.90, epsilon 0.50
# Total epochs: 142
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.90, epsilon 0.60
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.90, epsilon 0.70
# Total epochs: 115
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.90, epsilon 0.80
# Total epochs: 117
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.90, epsilon 0.90
# Total epochs: 138
# Total penalties: 0
# Testing: alpha 0.90, gamma 0.90, epsilon 1.00
# Total epochs: 129
# Total penalties: 0
# Testing: alpha 0.90, gamma 1.00, epsilon 0.10
# Total epochs: 135
# Total penalties: 0
# Testing: alpha 0.90, gamma 1.00, epsilon 0.20
# Total epochs: 137
# Total penalties: 0
# Testing: alpha 0.90, gamma 1.00, epsilon 0.30
# Total epochs: 125
# Total penalties: 0
# Testing: alpha 0.90, gamma 1.00, epsilon 0.40
# Total epochs: 124
# Total penalties: 0
# Testing: alpha 0.90, gamma 1.00, epsilon 0.50
# Total epochs: 125
# Total penalties: 0
# Testing: alpha 0.90, gamma 1.00, epsilon 0.60
# Total epochs: 143
# Total penalties: 0
# Testing: alpha 0.90, gamma 1.00, epsilon 0.70
# Total epochs: 132
# Total penalties: 0
# Testing: alpha 0.90, gamma 1.00, epsilon 0.80
# Total epochs: 125
# Total penalties: 0
# Testing: alpha 0.90, gamma 1.00, epsilon 0.90
# Total epochs: 136
# Total penalties: 0
# Testing: alpha 0.90, gamma 1.00, epsilon 1.00
# Total epochs: 133
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.10, epsilon 0.10
# Total epochs: 120
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.10, epsilon 0.20
# Total epochs: 204
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.10, epsilon 0.30
# Total epochs: 216
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.10, epsilon 0.40
# Total epochs: 392
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.10, epsilon 0.50
# Total epochs: 228
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.10, epsilon 0.60
# Total epochs: 136
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.10, epsilon 0.70
# Total epochs: 205
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.10, epsilon 0.80
# Total epochs: 133
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.10, epsilon 0.90
# Total epochs: 121
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.10, epsilon 1.00
# Total epochs: 126
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.20, epsilon 0.10
# Total epochs: 210
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.20, epsilon 0.20
# Total epochs: 202
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.20, epsilon 0.30
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.20, epsilon 0.40
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.20, epsilon 0.50
# Total epochs: 126
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.20, epsilon 0.60
# Total epochs: 142
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.20, epsilon 0.70
# Total epochs: 138
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.20, epsilon 0.80
# Total epochs: 124
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.20, epsilon 0.90
# Total epochs: 135
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.20, epsilon 1.00
# Total epochs: 118
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.30, epsilon 0.10
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.30, epsilon 0.20
# Total epochs: 235
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.30, epsilon 0.30
# Total epochs: 218
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.30, epsilon 0.40
# Total epochs: 308
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.30, epsilon 0.50
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.30, epsilon 0.60
# Total epochs: 139
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.30, epsilon 0.70
# Total epochs: 214
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.30, epsilon 0.80
# Total epochs: 127
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.30, epsilon 0.90
# Total epochs: 143
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.30, epsilon 1.00
# Total epochs: 142
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.40, epsilon 0.10
# Total epochs: 125
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.40, epsilon 0.20
# Total epochs: 126
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.40, epsilon 0.30
# Total epochs: 125
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.40, epsilon 0.40
# Total epochs: 216
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.40, epsilon 0.50
# Total epochs: 138
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.40, epsilon 0.60
# Total epochs: 129
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.40, epsilon 0.70
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.40, epsilon 0.80
# Total epochs: 135
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.40, epsilon 0.90
# Total epochs: 151
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.40, epsilon 1.00
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.50, epsilon 0.10
# Total epochs: 215
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.50, epsilon 0.20
# Total epochs: 118
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.50, epsilon 0.30
# Total epochs: 139
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.50, epsilon 0.40
# Total epochs: 140
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.50, epsilon 0.50
# Total epochs: 216
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.50, epsilon 0.60
# Total epochs: 122
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.50, epsilon 0.70
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.50, epsilon 0.80
# Total epochs: 132
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.50, epsilon 0.90
# Total epochs: 132
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.50, epsilon 1.00
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.60, epsilon 0.10
# Total epochs: 140
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.60, epsilon 0.20
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.60, epsilon 0.30
# Total epochs: 144
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.60, epsilon 0.40
# Total epochs: 136
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.60, epsilon 0.50
# Total epochs: 117
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.60, epsilon 0.60
# Total epochs: 138
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.60, epsilon 0.70
# Total epochs: 122
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.60, epsilon 0.80
# Total epochs: 146
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.60, epsilon 0.90
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.60, epsilon 1.00
# Total epochs: 127
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.70, epsilon 0.10
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.70, epsilon 0.20
# Total epochs: 134
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.70, epsilon 0.30
# Total epochs: 110
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.70, epsilon 0.40
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.70, epsilon 0.50
# Total epochs: 136
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.70, epsilon 0.60
# Total epochs: 133
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.70, epsilon 0.70
# Total epochs: 141
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.70, epsilon 0.80
# Total epochs: 124
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.70, epsilon 0.90
# Total epochs: 127
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.70, epsilon 1.00
# Total epochs: 138
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.80, epsilon 0.10
# Total epochs: 141
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.80, epsilon 0.20
# Total epochs: 132
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.80, epsilon 0.30
# Total epochs: 127
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.80, epsilon 0.40
# Total epochs: 121
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.80, epsilon 0.50
# Total epochs: 127
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.80, epsilon 0.60
# Total epochs: 124
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.80, epsilon 0.70
# Total epochs: 133
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.80, epsilon 0.80
# Total epochs: 134
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.80, epsilon 0.90
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.80, epsilon 1.00
# Total epochs: 140
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.90, epsilon 0.10
# Total epochs: 225
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.90, epsilon 0.20
# Total epochs: 127
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.90, epsilon 0.30
# Total epochs: 144
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.90, epsilon 0.40
# Total epochs: 219
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.90, epsilon 0.50
# Total epochs: 127
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.90, epsilon 0.60
# Total epochs: 142
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.90, epsilon 0.70
# Total epochs: 142
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.90, epsilon 0.80
# Total epochs: 124
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.90, epsilon 0.90
# Total epochs: 132
# Total penalties: 0
# Testing: alpha 1.00, gamma 0.90, epsilon 1.00
# Total epochs: 126
# Total penalties: 0
# Testing: alpha 1.00, gamma 1.00, epsilon 0.10
# Total epochs: 214
# Total penalties: 0
# Testing: alpha 1.00, gamma 1.00, epsilon 0.20
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 1.00, gamma 1.00, epsilon 0.30
# Total epochs: 148
# Total penalties: 0
# Testing: alpha 1.00, gamma 1.00, epsilon 0.40
# Total epochs: 118
# Total penalties: 0
# Testing: alpha 1.00, gamma 1.00, epsilon 0.50
# Total epochs: 130
# Total penalties: 0
# Testing: alpha 1.00, gamma 1.00, epsilon 0.60
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 1.00, gamma 1.00, epsilon 0.70
# Total epochs: 125
# Total penalties: 0
# Testing: alpha 1.00, gamma 1.00, epsilon 0.80
# Total epochs: 131
# Total penalties: 0
# Testing: alpha 1.00, gamma 1.00, epsilon 0.90
# Total epochs: 128
# Total penalties: 0
# Testing: alpha 1.00, gamma 1.00, epsilon 1.00
# Total epochs: 124
# Total penalties: 0

# %% [markdown]
# Uzyskane najlepsze parametry po przeszukaniu wszystkich kombinacji hiperparametrów z krokiem równym 0.1.

# %%
# Best parameters
alpha = 0.7
gamma = 0.2
epsilon = 0.8

# %% [markdown]
# Sprawdzam czy otrzymane hiperparamatery są faktycznie lepsze od pierwotnych

# %%
q_tabela = Q_learning(alpha, gamma, epsilon, 100000, np.zeros([env.observation_space.n, env.action_space.n]), env)
episodes, total_epochs, total_penalties = evaluate(1000, q_tabela, env, 100, False)

print(f"Episodes: {episodes}")
print(f"Avarage epochs per episode: {total_epochs/episodes}")
print(f"Avarage penalties per episode: {total_penalties/episodes}")
# Out:
# Episodes: 1000
# Avarage epochs per episode: 13.046
# Avarage penalties per episode: 0.0

# %% [markdown]
# Otrzymany wynik jest nieznacznie lepszy niż dla poprzednich hiperparametrów. Może mieć na to wpływ to że w przypadku przeszukania wszystkich hiperparametrów uczyliśmy agenta przez zaledwie 1000 różnych kombinacji, a w przypadku już ostatecznego testu użyliśmy aż 100000 różnych scenariuszy. Po paru testach zauważyłem że w przypadku aż tylu iteracji większość kombinacji hiperparametrów będzie dobrze działała a średni czas odcinka wynosić będzie 13. Sprawdze w takim razie czy w przypadku użycia 1000 scenariuszy coś się zmieni.

# %% [markdown]
# Dla pierwotnych hiperparametrów

# %%
# Example hiperparameters
alpha = 0.8
gamma = 0.6
epsilon = 0.7
scenarios = 1000
q_tabela = Q_learning(alpha, gamma, epsilon, scenarios, np.zeros([env.observation_space.n, env.action_space.n]), env)
episodes, total_epochs, total_penalties = evaluate(1000, q_tabela, env, 100, False)

print(f"Episodes: {episodes}")
print(f"Avarage epochs per episode: {total_epochs/episodes}")
print(f"Avarage penalties per episode: {total_penalties/episodes}")
# Out:
# Episodes: 1000
# Avarage epochs per episode: 15.607
# Avarage penalties per episode: 0.0

# %% [markdown]
# Dla uzyskanych hiperparametrów

# %%
# Best parameters
alpha = 0.7
gamma = 0.2
epsilon = 0.8
scenarios = 1000
q_tabela = Q_learning(alpha, gamma, epsilon, scenarios, np.zeros([env.observation_space.n, env.action_space.n]), env)
episodes, total_epochs, total_penalties = evaluate(1000, q_tabela, env, 100, False)

print(f"Episodes: {episodes}")
print(f"Avarage epochs per episode: {total_epochs/episodes}")
print(f"Avarage penalties per episode: {total_penalties/episodes}")
# Out:
# Episodes: 1000
# Avarage epochs per episode: 13.87
# Avarage penalties per episode: 0.0

# %% [markdown]
# Otrzymany wynik dla najlepszych hiperparametrów jest lepszy niż dla pierwotnych. Co najważniejsze czas uczenia agenta zmniejszył się do zaledwie 5s w porównaniu do poprzedniego przy tescie dla 100000 scenariuszy gdzie wynosił on około 1m. Mimo zmniejszenia ilości scenariuszy uczących wynik nie uległ znacznemu pogorszeniu.
